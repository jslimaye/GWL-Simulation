# %% [markdown]
# # Rainfall and Ground Water Data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gwl_data = pd.read_csv("GWL_final.csv")
gwl_data.head()
# Out:
#                station   Ane  Bhadalwadi  Bukum  Dhumalwadi  Dorlewadi  \
# 0  2000-01-01 00:00:00  5.00        2.40   0.55        5.50       4.60
# 1  2000-05-01 00:00:00  4.43        1.58   0.84        7.95        NaN
# 2  2000-08-01 00:00:00  3.07        0.01   0.34        8.54       5.15
# 3  2000-11-01 00:00:00  4.66        0.45   0.47       12.56       4.55
# 4  2001-01-01 00:00:00  5.38        0.13   0.67       10.80       6.33
#
#    Jejuri  Junnar  Karanje  Kolwan  ...  Belhe-1  Kamunde  Khadki  Wagholi-1  \
# 0    1.40    4.40     6.40    1.30  ...      NaN      NaN     NaN        NaN
# 1    3.20    5.38     5.22    1.64  ...      NaN      NaN     NaN        NaN
# 2    1.94    4.23     5.20    0.01  ...      NaN      NaN     NaN        NaN
# 3    5.60    4.09     8.04    0.90  ...      NaN      NaN     NaN        NaN
# 4    4.95    5.16     6.93    1.23  ...      NaN      NaN     NaN        NaN
#
#    Zendewadi-1  Baramati  Khutbhav_1  Parawadi  Kauthe_1  Khadakwasala_3
# 0          NaN       NaN         NaN       NaN       NaN             NaN
# 1          NaN       NaN         NaN       NaN       NaN             NaN
# 2          NaN       NaN         NaN       NaN       NaN             NaN
# 3          NaN       NaN         NaN       NaN       NaN             NaN
# 4          NaN       NaN         NaN       NaN       NaN             NaN
#
# [5 rows x 48 columns]

# %%
gwl_data.isna().sum()
# Out:
# station                  0
# Ane                     13
# Bhadalwadi              16
# Bukum                   15
# Dhumalwadi              12
# Dorlewadi                9
# Jejuri                   7
# Junnar                  10
# Karanje                  6
# Kolwan                   9
# Lonawala                 8
# Loni (Ambegaon)         10
# Mulshi                  25
# Narayangaon              5
# Narayanpur              14
# Nimbgaon-Ketke          15
# Otur                     6
# Pangre Sailar Basti     10
# Parne                    6
# Patas                    5
# Pimpri (Kh) Malvasti     5
# Pune                     6
# Rajgurnagar (Khed)       8
# Sakurde                  7
# Shivpur Khed            10
# Undavri Kade Pathar     11
# Wehle                   11
# Khutbhav_Pz             37
# Mahalunge Padval_Pz     51
# Pabal New               48
# Kharabwadi              57
# Shikrapur               50
# Ausari Khurd-1          60
# Kamatwadi-Walha         56
# Kamshet                 54
# Kasurdi-1               58
# Kolawade                56
# Ale-1                   57
# Belhe-1                 57
# Kamunde                 64
# Khadki                  61
# Wagholi-1               61
# Zendewadi-1             60
# Baramati                76
# Khutbhav_1              88
# Parawadi                88
# Kauthe_1                89
# Khadakwasala_3          89
# dtype: int64

# %%
gwl_data['station'].duplicated().sum()
# Out:
# 0

# %%
gwl_data.rename(columns={'station':'Date'},inplace=True)
gwl_data['Date'] = pd.to_datetime(gwl_data['Date'])
gwl_data.head()
# Out:
#         Date   Ane  Bhadalwadi  Bukum  Dhumalwadi  Dorlewadi  Jejuri  Junnar  \
# 0 2000-01-01  5.00        2.40   0.55        5.50       4.60    1.40    4.40
# 1 2000-05-01  4.43        1.58   0.84        7.95        NaN    3.20    5.38
# 2 2000-08-01  3.07        0.01   0.34        8.54       5.15    1.94    4.23
# 3 2000-11-01  4.66        0.45   0.47       12.56       4.55    5.60    4.09
# 4 2001-01-01  5.38        0.13   0.67       10.80       6.33    4.95    5.16
#
#    Karanje  Kolwan  ...  Belhe-1  Kamunde  Khadki  Wagholi-1  Zendewadi-1  \
# 0     6.40    1.30  ...      NaN      NaN     NaN        NaN          NaN
# 1     5.22    1.64  ...      NaN      NaN     NaN        NaN          NaN
# 2     5.20    0.01  ...      NaN      NaN     NaN        NaN          NaN
# 3     8.04    0.90  ...      NaN      NaN     NaN        NaN          NaN
# 4     6.93    1.23  ...      NaN      NaN     NaN        NaN          NaN
#
#    Baramati  Khutbhav_1  Parawadi  Kauthe_1  Khadakwasala_3
# 0       NaN         NaN       NaN       NaN             NaN
# 1       NaN         NaN       NaN       NaN             NaN
# 2       NaN         NaN       NaN       NaN             NaN
# 3       NaN         NaN       NaN       NaN             NaN
# 4       NaN         NaN       NaN       NaN             NaN
#
# [5 rows x 48 columns]

# %%
print(gwl_data.Date.dtype)
# Out:
# datetime64[ns]

# %%
len(gwl_data.columns)
# Out:
# 48

# %%
print(gwl_data.isna().sum() > 45)
# Out:
# Date                    False
# Ane                     False
# Bhadalwadi              False
# Bukum                   False
# Dhumalwadi              False
# Dorlewadi               False
# Jejuri                  False
# Junnar                  False
# Karanje                 False
# Kolwan                  False
# Lonawala                False
# Loni (Ambegaon)         False
# Mulshi                  False
# Narayangaon             False
# Narayanpur              False
# Nimbgaon-Ketke          False
# Otur                    False
# Pangre Sailar Basti     False
# Parne                   False
# Patas                   False
# Pimpri (Kh) Malvasti    False
# Pune                    False
# Rajgurnagar (Khed)      False
# Sakurde                 False
# Shivpur Khed            False
# Undavri Kade Pathar     False
# Wehle                   False
# Khutbhav_Pz             False
# Mahalunge Padval_Pz      True
# Pabal New                True
# Kharabwadi               True
# Shikrapur                True
# Ausari Khurd-1           True
# Kamatwadi-Walha          True
# Kamshet                  True
# Kasurdi-1                True
# Kolawade                 True
# Ale-1                    True
# Belhe-1                  True
# Kamunde                  True
# Khadki                   True
# Wagholi-1                True
# Zendewadi-1              True
# Baramati                 True
# Khutbhav_1               True
# Parawadi                 True
# Kauthe_1                 True
# Khadakwasala_3           True
# dtype: bool

# %%
plt.figure(figsize=(20, 10))
for col in gwl_data.columns[1:]:
    plt.plot(gwl_data['Date'], gwl_data[col], label=col)
plt.show()

# %%
rainfall_data = pd.read_csv("rain_final.csv")
rainfall_data.head()
# Out:
#   DateTime                Month  Rainfall
# 0  2000-01  2000-01-16 00:00:00  0.000000
# 1  2000-02  2000-02-15 00:00:00  0.000000
# 2  2000-03  2000-03-16 00:00:00  0.000000
# 3  2000-04  2000-04-15 12:00:00  0.000000
# 4  2000-05  2000-05-16 00:00:00  0.776626

# %%
rainfall_data.drop(columns=['Month'],inplace=True)

# %%
rainfall_data['DateTime'] = pd.to_datetime(rainfall_data['DateTime'])

# %%
rainfall_data.rename(columns = {'DateTime':'Date'},inplace=True)

# %%
print(rainfall_data.columns[0])
# Out:
# Date

# %%
gwl_rain = pd.merge(rainfall_data, gwl_data, on='Date',how='right')
gwl_rain.head()
# Out:
#         Date  Rainfall   Ane  Bhadalwadi  Bukum  Dhumalwadi  Dorlewadi  \
# 0 2000-01-01  0.000000  5.00        2.40   0.55        5.50       4.60
# 1 2000-05-01  0.776626  4.43        1.58   0.84        7.95        NaN
# 2 2000-08-01  2.647732  3.07        0.01   0.34        8.54       5.15
# 3 2000-11-01  0.474960  4.66        0.45   0.47       12.56       4.55
# 4 2001-01-01  0.208187  5.38        0.13   0.67       10.80       6.33
#
#    Jejuri  Junnar  Karanje  ...  Belhe-1  Kamunde  Khadki  Wagholi-1  \
# 0    1.40    4.40     6.40  ...      NaN      NaN     NaN        NaN
# 1    3.20    5.38     5.22  ...      NaN      NaN     NaN        NaN
# 2    1.94    4.23     5.20  ...      NaN      NaN     NaN        NaN
# 3    5.60    4.09     8.04  ...      NaN      NaN     NaN        NaN
# 4    4.95    5.16     6.93  ...      NaN      NaN     NaN        NaN
#
#    Zendewadi-1  Baramati  Khutbhav_1  Parawadi  Kauthe_1  Khadakwasala_3
# 0          NaN       NaN         NaN       NaN       NaN             NaN
# 1          NaN       NaN         NaN       NaN       NaN             NaN
# 2          NaN       NaN         NaN       NaN       NaN             NaN
# 3          NaN       NaN         NaN       NaN       NaN             NaN
# 4          NaN       NaN         NaN       NaN       NaN             NaN
#
# [5 rows x 49 columns]

# %%
l = len(gwl_rain.columns)
print("No of. Columns: ", l)
dropper = list()
for col in gwl_rain.columns:
    if gwl_rain[col].isna().sum() > 0.7*gwl_rain.shape[0]: #Removing the columns that have mote than 70% missing values
        dropper.append(col)
print(len(dropper), "columns to dropped are: ",dropper)

gwl_rain.drop(columns = dropper, inplace=True)

gwl_rain.shape[0]
# gwl_rain.head()
# Out:
# No of. Columns:  49
# 5 columns to dropped are:  ['Baramati', 'Khutbhav_1', 'Parawadi', 'Kauthe_1', 'Khadakwasala_3']
# 92

# %%
gwl_rain['Rainfall'] = gwl_rain['Rainfall'].replace(0,0.001)
gwl_rain.head()
# Out:
#         Date  Rainfall   Ane  Bhadalwadi  Bukum  Dhumalwadi  Dorlewadi  \
# 0 2000-01-01  0.001000  5.00        2.40   0.55        5.50       4.60
# 1 2000-05-01  0.776626  4.43        1.58   0.84        7.95        NaN
# 2 2000-08-01  2.647732  3.07        0.01   0.34        8.54       5.15
# 3 2000-11-01  0.474960  4.66        0.45   0.47       12.56       4.55
# 4 2001-01-01  0.208187  5.38        0.13   0.67       10.80       6.33
#
#    Jejuri  Junnar  Karanje  ...  Kamatwadi-Walha  Kamshet  Kasurdi-1  \
# 0    1.40    4.40     6.40  ...              NaN      NaN        NaN
# 1    3.20    5.38     5.22  ...              NaN      NaN        NaN
# 2    1.94    4.23     5.20  ...              NaN      NaN        NaN
# 3    5.60    4.09     8.04  ...              NaN      NaN        NaN
# 4    4.95    5.16     6.93  ...              NaN      NaN        NaN
#
#    Kolawade  Ale-1  Belhe-1  Kamunde  Khadki  Wagholi-1  Zendewadi-1
# 0       NaN    NaN      NaN      NaN     NaN        NaN          NaN
# 1       NaN    NaN      NaN      NaN     NaN        NaN          NaN
# 2       NaN    NaN      NaN      NaN     NaN        NaN          NaN
# 3       NaN    NaN      NaN      NaN     NaN        NaN          NaN
# 4       NaN    NaN      NaN      NaN     NaN        NaN          NaN
#
# [5 rows x 44 columns]

# %%
##Predictive Imputation

df = gwl_rain

from sklearn.ensemble import RandomForestRegressor

# Convert Date column to datetime and extract time-based features
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month  # Capture seasonality
df['Year'] = df['Date'].dt.year

for col in gwl_rain.columns[2:-2]:
    #Seperate Known data from unknown data
    df_known = df[df[col].notna()]
    df_missing = df[df[col].isna()]

    #Training the model on known data
    X_train = df_known[['Rainfall', 'Month', 'Year']]
    y_train = df_known[col]
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    # Predict missing values
    X_missing = df_missing[['Rainfall', 'Month', 'Year']]
    df.loc[df[col].isna(), col] = model.predict(X_missing)

# %%
gwl_rain.head()
# Out:
#         Date  Rainfall   Ane  Bhadalwadi  Bukum  Dhumalwadi  Dorlewadi  \
# 0 2000-01-01  0.001000  5.00        2.40   0.55        5.50      4.600
# 1 2000-05-01  0.776626  4.43        1.58   0.84        7.95      5.664
# 2 2000-08-01  2.647732  3.07        0.01   0.34        8.54      5.150
# 3 2000-11-01  0.474960  4.66        0.45   0.47       12.56      4.550
# 4 2001-01-01  0.208187  5.38        0.13   0.67       10.80      6.330
#
#    Jejuri  Junnar  Karanje  ...  Kasurdi-1  Kolawade    Ale-1  Belhe-1  \
# 0    1.40    4.40     6.40  ...     5.5213    4.3063  10.7831  13.0093
# 1    3.20    5.38     5.22  ...     4.2708    4.9702  10.3325  14.3558
# 2    1.94    4.23     5.20  ...     2.8827    3.0275   8.3702  11.6419
# 3    5.60    4.09     8.04  ...     3.3100    3.3908   5.9060   3.7187
# 4    4.95    5.16     6.93  ...     4.4962    4.3755  10.8418  13.7385
#
#    Kamunde  Khadki  Wagholi-1  Zendewadi-1  Month  Year
# 0   7.0902  4.8556     4.3151      11.4266      1  2000
# 1   9.5004  5.0241     4.7180       9.5727      5  2000
# 2   6.2306  2.0108     5.3265       4.0400      8  2000
# 3   6.5122  2.7736     4.6050       4.7448     11  2000
# 4   9.2532  5.2878     4.4234       9.5701      1  2001
#
# [5 rows x 46 columns]

# %%
gwl_rain.isna().sum()
# Out:
# Date                    0
# Rainfall                0
# Ane                     0
# Bhadalwadi              0
# Bukum                   0
# Dhumalwadi              0
# Dorlewadi               0
# Jejuri                  0
# Junnar                  0
# Karanje                 0
# Kolwan                  0
# Lonawala                0
# Loni (Ambegaon)         0
# Mulshi                  0
# Narayangaon             0
# Narayanpur              0
# Nimbgaon-Ketke          0
# Otur                    0
# Pangre Sailar Basti     0
# Parne                   0
# Patas                   0
# Pimpri (Kh) Malvasti    0
# Pune                    0
# Rajgurnagar (Khed)      0
# Sakurde                 0
# Shivpur Khed            0
# Undavri Kade Pathar     0
# Wehle                   0
# Khutbhav_Pz             0
# Mahalunge Padval_Pz     0
# Pabal New               0
# Kharabwadi              0
# Shikrapur               0
# Ausari Khurd-1          0
# Kamatwadi-Walha         0
# Kamshet                 0
# Kasurdi-1               0
# Kolawade                0
# Ale-1                   0
# Belhe-1                 0
# Kamunde                 0
# Khadki                  0
# Wagholi-1               0
# Zendewadi-1             0
# Month                   0
# Year                    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Plot original column1 with missing values
plt.figure(figsize=(12, 6))
plt.plot(gwl_rain['Date'], gwl_data['Khadki'], 'bo-', label='Original (With Missing)', alpha=0.8)  # Original data
plt.plot(gwl_rain['Date'], gwl_rain['Khadki'], 'ro-', label='Imputed (Regression)', alpha=0.2)  # Imputed data

# Formatting the plot
plt.xlabel('Date')
plt.ylabel('GWL Values')
plt.title('Comparison of Original and Imputed GWL Values for Khadki Station')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot original column1 with missing values
plt.figure(figsize=(12, 6))
plt.plot(gwl_rain['Date'], gwl_data['Bhadalwadi'], 'bo-', label='Original (With Missing)', alpha=0.8)  # Original data
plt.plot(gwl_rain['Date'], gwl_rain['Bhadalwadi'], 'ro-', label='Imputed (Regression)', alpha=0.2)  # Imputed data

# Formatting the plot
plt.xlabel('Date')
plt.ylabel('GWL Values')
plt.title('Comparison of Original and Imputed GWL Values for Bhadalwadi Station')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
gwl_rain.to_csv("gwl_rain_processed.csv")

# %% [markdown]
# # Pollution Data

# %%
wq_data= pd.read_csv("wq_final.csv")
wq_data.head()
# Out:
#            Month    pH dissolved_oxygen   BOD   COD Nitrate Fecal_Coliform  \
# 0   January-2012  7.61              1.2  13.5  44.0    0.26            350
# 1  February-2012  7.65              0.9  14.5  44.0    0.28            350
# 2     March-2012  7.26              BDL  17.0  52.0    1.68            425
# 3     April-2012  7.25                1  13.5  44.0    0.36            425
# 4       May-2012  8.24              1.3  15.0  44.0    0.26            550
#
#      WQI
# 0  36.09
# 1  34.65
# 2  33.23
# 3  37.12
# 4  30.46

# %%
wq_data.isna().sum()
# Out:
# Month               0
# pH                  1
# dissolved_oxygen    2
# BOD                 1
# COD                 2
# Nitrate             2
# Fecal_Coliform      7
# WQI                 1
# dtype: int64

# %%
wq_data['Month'] = pd.to_datetime(wq_data['Month'], format="%B-%Y")

# %%
wq_data.head()
# Out:
#        Month    pH dissolved_oxygen   BOD   COD Nitrate Fecal_Coliform    WQI
# 0 2012-01-01  7.61              1.2  13.5  44.0    0.26            350  36.09
# 1 2012-02-01  7.65              0.9  14.5  44.0    0.28            350  34.65
# 2 2012-03-01  7.26              BDL  17.0  52.0    1.68            425  33.23
# 3 2012-04-01  7.25                1  13.5  44.0    0.36            425  37.12
# 4 2012-05-01  8.24              1.3  15.0  44.0    0.26            550  30.46
